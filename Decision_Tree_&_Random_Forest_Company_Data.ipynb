# %% [markdown]
# <a href="https://colab.research.google.com/github/manasik29/Ensemble_Techniques/blob/main/Decision_Tree_%26_Random_Forest_Company_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Decision Tree
#
# Assignment
#
#
# About the data:
#
# Let’s consider a Company dataset with around 10 variables and 400 records.
#
# The attributes are as follows:
#
#  Sales -- Unit sales (in thousands) at each location
#
#  Competitor Price -- Price charged by competitor at each location
#
#  Income -- Community income level (in thousands of dollars)
#
#  Advertising -- Local advertising budget for company at each location (in thousands of dollars)
#
#  Population -- Population size in region (in thousands)
#
#  Price -- Price company charges for car seats at each site
#
#  Shelf Location at stores -- A factor with levels Bad, Good and Medium indicating the quality of the shelving location for the car seats at each site
#
#  Age -- Average age of the local population
#
#  Education -- Education level at each location
#
#  Urban -- A factor with levels No and Yes to indicate whether the store is in an urban or rural location
#
#  US -- A factor with levels No and Yes to indicate whether the store is in the US or not
#
# The company dataset looks like this:
#
# Problem Statement(Decision Tree):
#
# A cloth manufacturing company is interested to know about the segment or attributes causes high sale.
#
# Approach - A decision tree can be built with target variable Sale (we will first convert it in categorical variable) & all other variable will be independent in the analysis.
#
# Problem Statement(Random Forest):
# A cloth manufacturing company is interested to know about the segment or attributes causes high sale.
#
# Approach - A Random Forest can be built with target variable Sales (we will first convert it in categorical variable) & all other variable will be independent in the analysis.

# %% [markdown]
# # **Load data and libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %%
data = pd.read_csv('/content/Company_Data.csv')

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data.tail()
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes

# %% [markdown]
# # **EDA**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
data.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
sns.heatmap(data.isnull())

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sales, CompPrice, Income, Advertising, Population, Price, ShelveLoc, Age, Education, Urban, US]
# Index: []

# %% [markdown]
# We can conclude no duplicate and missing values in data.

# %% [markdown]
# Also the data types of columns seem correct for now.

# %%
data.shape
# Out:
# (400, 11)

# %% [markdown]
# # **Data Visualisation**

# %% [markdown]
# Continuous Columns

# %%
sns.distplot(data.Sales)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.CompPrice)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Income)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Advertising)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Price)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Population)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data.Education)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Outlier Detection
fig, axes=plt.subplots(4,2,figsize=(12,8),sharex=False,sharey=False)
sns.boxplot(x='Sales',data=data,ax=axes[0,0])
sns.boxplot(x='CompPrice',data=data,ax=axes[1,0])
sns.boxplot(x='Income',data=data,ax=axes[2,0])
sns.boxplot(x='Advertising',data=data,ax=axes[3,0])
sns.boxplot(x='Population',data=data,ax=axes[0,1])
sns.boxplot(x='Price',data=data,ax=axes[1,1])
sns.boxplot(x='Age',data=data,ax=axes[2,1])
sns.boxplot(x='Education',data=data,ax=axes[3,1])
plt.tight_layout(pad=2.0)

# %% [markdown]
# We can see outliers in Sales, CompPrice and Price.

# %% [markdown]
# We will try to treat outliers using SQRT, CBRT and LOG transformation

# %%
# Apply sqrt tansformation

fig, axes=plt.subplots(3,figsize=(5,5),sharex=False,sharey=False)
sns.boxplot(np.sqrt(data.Sales),ax=axes[0])
sns.boxplot(np.sqrt(data.CompPrice),ax=axes[1])
sns.boxplot(np.sqrt(data.Price),ax=axes[2])
plt.tight_layout(pad=2.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Apply cbrt tansformation

fig, axes=plt.subplots(3,figsize=(5,5),sharex=False,sharey=False)
sns.boxplot(np.cbrt(data.Sales),ax=axes[0])
sns.boxplot(np.cbrt(data.CompPrice),ax=axes[1])
sns.boxplot(np.cbrt(data.Price),ax=axes[2])
plt.tight_layout(pad=2.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Apply log tansformation

fig, axes=plt.subplots(3,figsize=(5,5),sharex=False,sharey=False)
sns.boxplot(np.log(data.Sales),ax=axes[0])
sns.boxplot(np.log(data.CompPrice),ax=axes[1])
sns.boxplot(np.log(data.Price),ax=axes[2])
plt.tight_layout(pad=2.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# None of the transformations were that effective in eliminating outliers.

# %% [markdown]
# Categorical Columns

# %%
data.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
data['ShelveLoc'].value_counts().plot.bar()
plt.xlabel('ShelveLoc')
print(data['ShelveLoc'].value_counts())
# Out:
# Medium    219
# Bad        96
# Good       85
# Name: ShelveLoc, dtype: int64

# %%
data['Urban'].value_counts().plot.bar()
plt.xlabel('Urban')
print(data['Urban'].value_counts())
# Out:
# Yes    282
# No     118
# Name: Urban, dtype: int64

# %%
data['US'].value_counts().plot.bar()
plt.xlabel('US')
print(data['US'].value_counts())
# Out:
# Yes    258
# No     142
# Name: US, dtype: int64

# %%
fig, axes=plt.subplots(2, figsize=(6,6),sharex=False,sharey=False)
sns.barplot(y= 'Sales',x ='US', data=data, ax=axes[0])
sns.barplot(y= 'Sales',x= 'ShelveLoc', data=data, ax=axes[1])
plt.tight_layout(pad=2.0)

# %% [markdown]
# **Observation**
#
# - As we can conclude from above plots, Sales is highly affcted if the Shelve Location quality. If the Shelve location quality is good, sales will increase.
#
# - Sales is also dependent on whether the store is in US or not. Sales is higher for stores in US.

# %%
sns.barplot(y= 'Advertising',x ='US', data=data)

# %% [markdown]
# **Observation**
#
# - The Advertising done in the US regions is very high. That means company has not done any advertising outside the US regions.

# %%
fig, axes=plt.subplots(2, figsize=(7,6),sharex=False,sharey=False)
sns.barplot(y= 'Sales',x ='US', hue='Urban', data=data, ax=axes[0])
sns.barplot(y= 'Sales',x= 'US', hue='ShelveLoc', data=data, ax=axes[1])
plt.tight_layout(pad=2.0)

# %% [markdown]
# **Observation**
#
# - The Shelve Location quality is is higher if the region is in US and hence the Sales are also higher in the US region stores.
#
# - We can observe sales is lower in the region in US if it is a Urban area.

# %% [markdown]
# **One Hot encoding**
#
# We will perform one hot encoding on US, Urban and ShelveLoc features.

# %%
df = pd.get_dummies(data)

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0                1               0                 0         0          1
# 1                0               1                 0         0          1
# 2                0               0                 1         0          1
# 3                0               0                 1         0          1
# 4                1               0                 0         0          1
# ..             ...             ...               ...       ...        ...
# 395              0               1                 0         0          1
# 396              0               0                 1         1          0
# 397              0               0                 1         0          1
# 398              1               0                 0         0          1
# 399              0               1                 0         0          1
#
#      US_No  US_Yes
# 0        0       1
# 1        0       1
# 2        0       1
# 3        0       1
# 4        1       0
# ..     ...     ...
# 395      0       1
# 396      0       1
# 397      0       1
# 398      0       1
# 399      0       1
#
# [400 rows x 15 columns]

# %% [markdown]
# **Dependency of Sales on other features**
#
# We can also check for dependency of Sales(target variable) on other features of data with correlation and PPS.

# %%
#correlation of Sales with other features
df.corr().iloc[0,:]
# Out:
# Sales               1.000000
# CompPrice           0.064079
# Income              0.151951
# Advertising         0.269507
# Population          0.050471
# Price              -0.444951
# Age                -0.231815
# Education          -0.051955
# ShelveLoc_Bad      -0.393167
# ShelveLoc_Good      0.500510
# ShelveLoc_Medium   -0.073999
# Urban_No            0.015419
# Urban_Yes          -0.015419
# US_No              -0.177093
# US_Yes              0.177093
# Name: Sales, dtype: float64

# %%
#PPS
# !pip install ppscore

# %%
import ppscore as pps

# %%
with pd.option_context("display.max_rows", None):
    display(pps.matrix(df))
# Out:
#                     x                 y   ppscore            case  \
# 0               Sales             Sales  1.000000  predict_itself
# 1               Sales         CompPrice  0.000000      regression
# 2               Sales            Income  0.000000      regression
# 3               Sales       Advertising  0.000000      regression
# 4               Sales        Population  0.000000      regression
# 5               Sales             Price  0.000000      regression
# 6               Sales               Age  0.000000      regression
# 7               Sales         Education  0.000000      regression
# 8               Sales     ShelveLoc_Bad  0.000000      regression
# 9               Sales    ShelveLoc_Good  0.000000      regression
# 10              Sales  ShelveLoc_Medium  0.057090      regression
# 11              Sales          Urban_No  0.000000      regression
# 12              Sales         Urban_Yes  0.000000      regression
# 13              Sales             US_No  0.000000      regression
# 14              Sales            US_Yes  0.000000      regression
# 15          CompPrice             Sales  0.000000      regression
# 16          CompPrice         CompPrice  1.000000  predict_itself
# 17          CompPrice            Income  0.000000      regression
# 18          CompPrice       Advertising  0.000000      regression
# 19          CompPrice        Population  0.000000      regression
# 20          CompPrice             Price  0.050512      regression
# 21          CompPrice               Age  0.000000      regression
# 22          CompPrice         Education  0.000000      regression
# 23          CompPrice     ShelveLoc_Bad  0.000000      regression
# 24          CompPrice    ShelveLoc_Good  0.000000      regression
# 25          CompPrice  ShelveLoc_Medium  0.000000      regression
# 26          CompPrice          Urban_No  0.000000      regression
# 27          CompPrice         Urban_Yes  0.000000      regression
# 28          CompPrice             US_No  0.000000      regression
# 29          CompPrice            US_Yes  0.000000      regression
# 30             Income             Sales  0.000000      regression
# 31             Income         CompPrice  0.000000      regression
# 32             Income            Income  1.000000  predict_itself
# 33             Income       Advertising  0.000000      regression
# 34             Income        Population  0.000000      regression
# 35             Income             Price  0.000000      regression
# 36             Income               Age  0.000000      regression
# 37             Income         Education  0.000000      regression
# 38             Income     ShelveLoc_Bad  0.000000      regression
# 39             Income    ShelveLoc_Good  0.000000      regression
# 40             Income  ShelveLoc_Medium  0.000000      regression
# 41             Income          Urban_No  0.000000      regression
# 42             Income         Urban_Yes  0.000000      regression
# 43             Income             US_No  0.000000      regression
# 44             Income            US_Yes  0.000000      regression
# 45        Advertising             Sales  0.000000      regression
# 46        Advertising         CompPrice  0.000000      regression
# 47        Advertising            Income  0.000000      regression
# 48        Advertising       Advertising  1.000000  predict_itself
# 49        Advertising        Population  0.013404      regression
# 50        Advertising             Price  0.000000      regression
# 51        Advertising               Age  0.000000      regression
# 52        Advertising         Education  0.000000      regression
# 53        Advertising     ShelveLoc_Bad  0.000000      regression
# 54        Advertising    ShelveLoc_Good  0.000000      regression
# 55        Advertising  ShelveLoc_Medium  0.000000      regression
# 56        Advertising          Urban_No  0.000000      regression
# 57        Advertising         Urban_Yes  0.000000      regression
# 58        Advertising             US_No  0.560806      regression
# 59        Advertising            US_Yes  0.560806      regression
# 60         Population             Sales  0.000000      regression
# 61         Population         CompPrice  0.000000      regression
# 62         Population            Income  0.000000      regression
# 63         Population       Advertising  0.000000      regression
# 64         Population        Population  1.000000  predict_itself
# 65         Population             Price  0.000000      regression
# 66         Population               Age  0.000000      regression
# 67         Population         Education  0.000000      regression
# 68         Population     ShelveLoc_Bad  0.000000      regression
# 69         Population    ShelveLoc_Good  0.000000      regression
# 70         Population  ShelveLoc_Medium  0.000000      regression
# 71         Population          Urban_No  0.000000      regression
# 72         Population         Urban_Yes  0.000000      regression
# 73         Population             US_No  0.000000      regression
# 74         Population            US_Yes  0.000000      regression
# 75              Price             Sales  0.000000      regression
# 76              Price         CompPrice  0.073580      regression
# 77              Price            Income  0.000000      regression
# 78              Price       Advertising  0.002103      regression
# 79              Price        Population  0.000000      regression
# 80              Price             Price  1.000000  predict_itself
# 81              Price               Age  0.000000      regression
# 82              Price         Education  0.000000      regression
# 83              Price     ShelveLoc_Bad  0.000000      regression
# 84              Price    ShelveLoc_Good  0.000000      regression
# 85              Price  ShelveLoc_Medium  0.000000      regression
# 86              Price          Urban_No  0.000000      regression
# 87              Price         Urban_Yes  0.000000      regression
# 88              Price             US_No  0.000000      regression
# 89              Price            US_Yes  0.000000      regression
# 90                Age             Sales  0.000000      regression
# 91                Age         CompPrice  0.000000      regression
# 92                Age            Income  0.000000      regression
# 93                Age       Advertising  0.000000      regression
# 94                Age        Population  0.000000      regression
# 95                Age             Price  0.000000      regression
# 96                Age               Age  1.000000  predict_itself
# 97                Age         Education  0.000000      regression
# 98                Age     ShelveLoc_Bad  0.000000      regression
# 99                Age    ShelveLoc_Good  0.000000      regression
# 100               Age  ShelveLoc_Medium  0.000000      regression
# 101               Age          Urban_No  0.000000      regression
# 102               Age         Urban_Yes  0.000000      regression
# 103               Age             US_No  0.000000      regression
# 104               Age            US_Yes  0.000000      regression
# 105         Education             Sales  0.000000      regression
# 106         Education         CompPrice  0.000000      regression
# 107         Education            Income  0.000000      regression
# 108         Education       Advertising  0.000000      regression
# 109         Education        Population  0.000000      regression
# 110         Education             Price  0.000000      regression
# 111         Education               Age  0.000000      regression
# 112         Education         Education  1.000000  predict_itself
# 113         Education     ShelveLoc_Bad  0.000000      regression
# 114         Education    ShelveLoc_Good  0.000000      regression
# 115         Education  ShelveLoc_Medium  0.000000      regression
# 116         Education          Urban_No  0.000000      regression
# 117         Education         Urban_Yes  0.000000      regression
# 118         Education             US_No  0.000000      regression
# 119         Education            US_Yes  0.000000      regression
# 120     ShelveLoc_Bad             Sales  0.070603      regression
# 121     ShelveLoc_Bad         CompPrice  0.000000      regression
# 122     ShelveLoc_Bad            Income  0.000000      regression
# 123     ShelveLoc_Bad       Advertising  0.000000      regression
# 124     ShelveLoc_Bad        Population  0.000000      regression
# 125     ShelveLoc_Bad             Price  0.000000      regression
# 126     ShelveLoc_Bad               Age  0.000000      regression
# 127     ShelveLoc_Bad         Education  0.000000      regression
# 128     ShelveLoc_Bad     ShelveLoc_Bad  1.000000  predict_itself
# 129     ShelveLoc_Bad    ShelveLoc_Good  0.000000      regression
# 130     ShelveLoc_Bad  ShelveLoc_Medium  0.320281      regression
# 131     ShelveLoc_Bad          Urban_No  0.000000      regression
# 132     ShelveLoc_Bad         Urban_Yes  0.000000      regression
# 133     ShelveLoc_Bad             US_No  0.000000      regression
# 134     ShelveLoc_Bad            US_Yes  0.000000      regression
# 135    ShelveLoc_Good             Sales  0.106857      regression
# 136    ShelveLoc_Good         CompPrice  0.000000      regression
# 137    ShelveLoc_Good            Income  0.000000      regression
# 138    ShelveLoc_Good       Advertising  0.000000      regression
# 139    ShelveLoc_Good        Population  0.000000      regression
# 140    ShelveLoc_Good             Price  0.000000      regression
# 141    ShelveLoc_Good               Age  0.000000      regression
# 142    ShelveLoc_Good         Education  0.000000      regression
# 143    ShelveLoc_Good     ShelveLoc_Bad  0.000000      regression
# 144    ShelveLoc_Good    ShelveLoc_Good  1.000000  predict_itself
# 145    ShelveLoc_Good  ShelveLoc_Medium  0.259662      regression
# 146    ShelveLoc_Good          Urban_No  0.000000      regression
# 147    ShelveLoc_Good         Urban_Yes  0.000000      regression
# 148    ShelveLoc_Good             US_No  0.000000      regression
# 149    ShelveLoc_Good            US_Yes  0.000000      regression
# 150  ShelveLoc_Medium             Sales  0.000000      regression
# 151  ShelveLoc_Medium         CompPrice  0.000000      regression
# 152  ShelveLoc_Medium            Income  0.000000      regression
# 153  ShelveLoc_Medium       Advertising  0.000000      regression
# 154  ShelveLoc_Medium        Population  0.000000      regression
# 155  ShelveLoc_Medium             Price  0.000000      regression
# 156  ShelveLoc_Medium               Age  0.000000      regression
# 157  ShelveLoc_Medium         Education  0.000000      regression
# 158  ShelveLoc_Medium     ShelveLoc_Bad  0.059708      regression
# 159  ShelveLoc_Medium    ShelveLoc_Good  0.000000      regression
# 160  ShelveLoc_Medium  ShelveLoc_Medium  1.000000  predict_itself
# 161  ShelveLoc_Medium          Urban_No  0.000000      regression
# 162  ShelveLoc_Medium         Urban_Yes  0.000000      regression
# 163  ShelveLoc_Medium             US_No  0.000000      regression
# 164  ShelveLoc_Medium            US_Yes  0.000000      regression
# 165          Urban_No             Sales  0.000000      regression
# 166          Urban_No         CompPrice  0.001530      regression
# 167          Urban_No            Income  0.000000      regression
# 168          Urban_No       Advertising  0.000000      regression
# 169          Urban_No        Population  0.000000      regression
# 170          Urban_No             Price  0.000000      regression
# 171          Urban_No               Age  0.000000      regression
# 172          Urban_No         Education  0.000000      regression
# 173          Urban_No     ShelveLoc_Bad  0.000000      regression
# 174          Urban_No    ShelveLoc_Good  0.000000      regression
# 175          Urban_No  ShelveLoc_Medium  0.000000      regression
# 176          Urban_No          Urban_No  1.000000  predict_itself
# 177          Urban_No         Urban_Yes  1.000000      regression
# 178          Urban_No             US_No  0.000000      regression
# 179          Urban_No            US_Yes  0.000000      regression
# 180         Urban_Yes             Sales  0.000000      regression
# 181         Urban_Yes         CompPrice  0.001530      regression
# 182         Urban_Yes            Income  0.000000      regression
# 183         Urban_Yes       Advertising  0.000000      regression
# 184         Urban_Yes        Population  0.000000      regression
# 185         Urban_Yes             Price  0.000000      regression
# 186         Urban_Yes               Age  0.000000      regression
# 187         Urban_Yes         Education  0.000000      regression
# 188         Urban_Yes     ShelveLoc_Bad  0.000000      regression
# 189         Urban_Yes    ShelveLoc_Good  0.000000      regression
# 190         Urban_Yes  ShelveLoc_Medium  0.000000      regression
# 191         Urban_Yes          Urban_No  1.000000      regression
# 192         Urban_Yes         Urban_Yes  1.000000  predict_itself
# 193         Urban_Yes             US_No  0.000000      regression
# 194         Urban_Yes            US_Yes  0.000000      regression
# 195             US_No             Sales  0.008463      regression
# 196             US_No         CompPrice  0.000000      regression
# 197             US_No            Income  0.000000      regression
# 198             US_No       Advertising  0.413068      regression
# 199             US_No        Population  0.000017      regression
# 200             US_No             Price  0.000000      regression
# 201             US_No               Age  0.000000      regression
# 202             US_No         Education  0.000000      regression
# 203             US_No     ShelveLoc_Bad  0.000000      regression
# 204             US_No    ShelveLoc_Good  0.000000      regression
# 205             US_No  ShelveLoc_Medium  0.000000      regression
# 206             US_No          Urban_No  0.000000      regression
# 207             US_No         Urban_Yes  0.000000      regression
# 208             US_No             US_No  1.000000  predict_itself
# 209             US_No            US_Yes  1.000000      regression
# 210            US_Yes             Sales  0.008463      regression
# 211            US_Yes         CompPrice  0.000000      regression
# 212            US_Yes            Income  0.000000      regression
# 213            US_Yes       Advertising  0.413068      regression
# 214            US_Yes        Population  0.000017      regression
# 215            US_Yes             Price  0.000000      regression
# 216            US_Yes               Age  0.000000      regression
# 217            US_Yes         Education  0.000000      regression
# 218            US_Yes     ShelveLoc_Bad  0.000000      regression
# 219            US_Yes    ShelveLoc_Good  0.000000      regression
# 220            US_Yes  ShelveLoc_Medium  0.000000      regression
# 221            US_Yes          Urban_No  0.000000      regression
# 222            US_Yes         Urban_Yes  0.000000      regression
# 223            US_Yes             US_No  1.000000      regression
# 224            US_Yes            US_Yes  1.000000  predict_itself
#
#      is_valid_score               metric  baseline_score  model_score  \
# 0              True                 None        0.000000     1.000000
# 1              True  mean absolute error       12.215000    17.223333
# 2              True  mean absolute error       23.632500    30.317083
# 3              True  mean absolute error        5.730000     6.332500
# 4              True  mean absolute error      127.045000   165.681250
# 5              True  mean absolute error       18.720000    23.392917
# 6              True  mean absolute error       13.877500    18.119167
# 7              True  mean absolute error        2.285000     2.811667
# 8              True  mean absolute error        0.240000     0.293750
# 9              True  mean absolute error        0.212500     0.223750
# 10             True  mean absolute error        0.452500     0.426667
# 11             True  mean absolute error        0.295000     0.420417
# 12             True  mean absolute error        0.295000     0.420417
# 13             True  mean absolute error        0.355000     0.427500
# 14             True  mean absolute error        0.355000     0.427500
# 15             True  mean absolute error        2.262175     2.725607
# 16             True                 None        0.000000     1.000000
# 17             True  mean absolute error       23.632500    26.852933
# 18             True  mean absolute error        5.730000     6.172658
# 19             True  mean absolute error      127.045000   135.316941
# 20             True  mean absolute error       18.720000    17.774408
# 21             True  mean absolute error       13.877500    15.042176
# 22             True  mean absolute error        2.285000     2.438975
# 23             True  mean absolute error        0.240000     0.384889
# 24             True  mean absolute error        0.212500     0.343929
# 25             True  mean absolute error        0.452500     0.480787
# 26             True  mean absolute error        0.295000     0.389960
# 27             True  mean absolute error        0.295000     0.389960
# 28             True  mean absolute error        0.355000     0.476109
# 29             True  mean absolute error        0.355000     0.476109
# 30             True  mean absolute error        2.262175     2.680521
# 31             True  mean absolute error       12.215000    13.589500
# 32             True                 None        0.000000     1.000000
# 33             True  mean absolute error        5.730000     6.307387
# 34             True  mean absolute error      127.045000   141.213515
# 35             True  mean absolute error       18.720000    22.308116
# 36             True  mean absolute error       13.877500    15.889122
# 37             True  mean absolute error        2.285000     2.609678
# 38             True  mean absolute error        0.240000     0.355670
# 39             True  mean absolute error        0.212500     0.361310
# 40             True  mean absolute error        0.452500     0.493503
# 41             True  mean absolute error        0.295000     0.426411
# 42             True  mean absolute error        0.295000     0.426411
# 43             True  mean absolute error        0.355000     0.452008
# 44             True  mean absolute error        0.355000     0.452008
# 45             True  mean absolute error        2.262175     2.307301
# 46             True  mean absolute error       12.215000    12.853502
# 47             True  mean absolute error       23.632500    24.304143
# 48             True                 None        0.000000     1.000000
# 49             True  mean absolute error      127.045000   125.342109
# 50             True  mean absolute error       18.720000    19.455599
# 51             True  mean absolute error       13.877500    14.408802
# 52             True  mean absolute error        2.285000     2.317564
# 53             True  mean absolute error        0.240000     0.369116
# 54             True  mean absolute error        0.212500     0.344499
# 55             True  mean absolute error        0.452500     0.484716
# 56             True  mean absolute error        0.295000     0.402986
# 57             True  mean absolute error        0.295000     0.402986
# 58             True  mean absolute error        0.355000     0.155914
# 59             True  mean absolute error        0.355000     0.155914
# 60             True  mean absolute error        2.262175     3.174025
# 61             True  mean absolute error       12.215000    16.331250
# 62             True  mean absolute error       23.632500    30.788750
# 63             True  mean absolute error        5.730000     6.853333
# 64             True                 None        0.000000     1.000000
# 65             True  mean absolute error       18.720000    24.647500
# 66             True  mean absolute error       13.877500    19.457083
# 67             True  mean absolute error        2.285000     2.872083
# 68             True  mean absolute error        0.240000     0.356250
# 69             True  mean absolute error        0.212500     0.336250
# 70             True  mean absolute error        0.452500     0.506667
# 71             True  mean absolute error        0.295000     0.380833
# 72             True  mean absolute error        0.295000     0.380833
# 73             True  mean absolute error        0.355000     0.525000
# 74             True  mean absolute error        0.355000     0.525000
# 75             True  mean absolute error        2.262175     2.357588
# 76             True  mean absolute error       12.215000    11.316214
# 77             True  mean absolute error       23.632500    27.485390
# 78             True  mean absolute error        5.730000     5.717949
# 79             True  mean absolute error      127.045000   145.510887
# 80             True                 None        0.000000     1.000000
# 81             True  mean absolute error       13.877500    15.362325
# 82             True  mean absolute error        2.285000     2.538187
# 83             True  mean absolute error        0.240000     0.390704
# 84             True  mean absolute error        0.212500     0.337141
# 85             True  mean absolute error        0.452500     0.509758
# 86             True  mean absolute error        0.295000     0.405837
# 87             True  mean absolute error        0.295000     0.405837
# 88             True  mean absolute error        0.355000     0.422126
# 89             True  mean absolute error        0.355000     0.422126
# 90             True  mean absolute error        2.262175     2.493357
# 91             True  mean absolute error       12.215000    13.784663
# 92             True  mean absolute error       23.632500    26.356650
# 93             True  mean absolute error        5.730000     5.854333
# 94             True  mean absolute error      127.045000   130.742623
# 95             True  mean absolute error       18.720000    20.796897
# 96             True                 None        0.000000     1.000000
# 97             True  mean absolute error        2.285000     2.454935
# 98             True  mean absolute error        0.240000     0.352852
# 99             True  mean absolute error        0.212500     0.334115
# 100            True  mean absolute error        0.452500     0.503713
# 101            True  mean absolute error        0.295000     0.401882
# 102            True  mean absolute error        0.295000     0.401882
# 103            True  mean absolute error        0.355000     0.460413
# 104            True  mean absolute error        0.355000     0.460413
# 105            True  mean absolute error        2.262175     2.319058
# 106            True  mean absolute error       12.215000    12.414703
# 107            True  mean absolute error       23.632500    23.824354
# 108            True  mean absolute error        5.730000     5.918552
# 109            True  mean absolute error      127.045000   127.956197
# 110            True  mean absolute error       18.720000    18.803442
# 111            True  mean absolute error       13.877500    14.093555
# 112            True                 None        0.000000     1.000000
# 113            True  mean absolute error        0.240000     0.363809
# 114            True  mean absolute error        0.212500     0.335565
# 115            True  mean absolute error        0.452500     0.494026
# 116            True  mean absolute error        0.295000     0.421842
# 117            True  mean absolute error        0.295000     0.421842
# 118            True  mean absolute error        0.355000     0.463086
# 119            True  mean absolute error        0.355000     0.463086
# 120            True  mean absolute error        2.262175     2.102459
# 121            True  mean absolute error       12.215000    12.223598
# 122            True  mean absolute error       23.632500    23.735338
# 123            True  mean absolute error        5.730000     5.840314
# 124            True  mean absolute error      127.045000   127.045275
# 125            True  mean absolute error       18.720000    18.866664
# 126            True  mean absolute error       13.877500    13.959282
# 127            True  mean absolute error        2.285000     2.301669
# 128            True                 None        0.000000     1.000000
# 129            True  mean absolute error        0.212500     0.307573
# 130            True  mean absolute error        0.452500     0.307573
# 131            True  mean absolute error        0.295000     0.414851
# 132            True  mean absolute error        0.295000     0.414851
# 133            True  mean absolute error        0.355000     0.462060
# 134            True  mean absolute error        0.355000     0.462060
# 135            True  mean absolute error        2.262175     2.020446
# 136            True  mean absolute error       12.215000    12.272576
# 137            True  mean absolute error       23.632500    23.706183
# 138            True  mean absolute error        5.730000     5.816015
# 139            True  mean absolute error      127.045000   127.519496
# 140            True  mean absolute error       18.720000    18.779985
# 141            True  mean absolute error       13.877500    13.977811
# 142            True  mean absolute error        2.285000     2.302568
# 143            True  mean absolute error        0.240000     0.335003
# 144            True                 None        0.000000     1.000000
# 145            True  mean absolute error        0.452500     0.335003
# 146            True  mean absolute error        0.295000     0.416872
# 147            True  mean absolute error        0.295000     0.416872
# 148            True  mean absolute error        0.355000     0.462396
# 149            True  mean absolute error        0.355000     0.462396
# 150            True  mean absolute error        2.262175     2.279635
# 151            True  mean absolute error       12.215000    12.239599
# 152            True  mean absolute error       23.632500    23.705698
# 153            True  mean absolute error        5.730000     5.818728
# 154            True  mean absolute error      127.045000   127.099288
# 155            True  mean absolute error       18.720000    18.839542
# 156            True  mean absolute error       13.877500    13.939707
# 157            True  mean absolute error        2.285000     2.305655
# 158            True  mean absolute error        0.240000     0.225670
# 159            True  mean absolute error        0.212500     0.225670
# 160            True                 None        0.000000     1.000000
# 161            True  mean absolute error        0.295000     0.416852
# 162            True  mean absolute error        0.295000     0.416852
# 163            True  mean absolute error        0.355000     0.459866
# 164            True  mean absolute error        0.355000     0.459866
# 165            True  mean absolute error        2.262175     2.277412
# 166            True  mean absolute error       12.215000    12.196311
# 167            True  mean absolute error       23.632500    23.633101
# 168            True  mean absolute error        5.730000     5.836508
# 169            True  mean absolute error      127.045000   127.971521
# 170            True  mean absolute error       18.720000    18.870647
# 171            True  mean absolute error       13.877500    14.019109
# 172            True  mean absolute error        2.285000     2.307619
# 173            True  mean absolute error        0.240000     0.363430
# 174            True  mean absolute error        0.212500     0.334628
# 175            True  mean absolute error        0.452500     0.496768
# 176            True                 None        0.000000     1.000000
# 177            True  mean absolute error        0.295000     0.000000
# 178            True  mean absolute error        0.355000     0.460786
# 179            True  mean absolute error        0.355000     0.460786
# 180            True  mean absolute error        2.262175     2.277412
# 181            True  mean absolute error       12.215000    12.196311
# 182            True  mean absolute error       23.632500    23.633101
# 183            True  mean absolute error        5.730000     5.836508
# 184            True  mean absolute error      127.045000   127.971521
# 185            True  mean absolute error       18.720000    18.870647
# 186            True  mean absolute error       13.877500    14.019109
# 187            True  mean absolute error        2.285000     2.307619
# 188            True  mean absolute error        0.240000     0.363430
# 189            True  mean absolute error        0.212500     0.334628
# 190            True  mean absolute error        0.452500     0.496768
# 191            True  mean absolute error        0.295000     0.000000
# 192            True                 None        0.000000     1.000000
# 193            True  mean absolute error        0.355000     0.460786
# 194            True  mean absolute error        0.355000     0.460786
# 195            True  mean absolute error        2.262175     2.243030
# 196            True  mean absolute error       12.215000    12.231232
# 197            True  mean absolute error       23.632500    23.657226
# 198            True  mean absolute error        5.730000     3.363122
# 199            True  mean absolute error      127.045000   127.042857
# 200            True  mean absolute error       18.720000    18.832390
# 201            True  mean absolute error       13.877500    13.956625
# 202            True  mean absolute error        2.285000     2.304601
# 203            True  mean absolute error        0.240000     0.367275
# 204            True  mean absolute error        0.212500     0.333927
# 205            True  mean absolute error        0.452500     0.496345
# 206            True  mean absolute error        0.295000     0.416724
# 207            True  mean absolute error        0.295000     0.416724
# 208            True                 None        0.000000     1.000000
# 209            True  mean absolute error        0.355000     0.000000
# 210            True  mean absolute error        2.262175     2.243030
# 211            True  mean absolute error       12.215000    12.231232
# 212            True  mean absolute error       23.632500    23.657226
# 213            True  mean absolute error        5.730000     3.363122
# 214            True  mean absolute error      127.045000   127.042857
# 215            True  mean absolute error       18.720000    18.832390
# 216            True  mean absolute error       13.877500    13.956625
# 217            True  mean absolute error        2.285000     2.304601
# 218            True  mean absolute error        0.240000     0.367275
# 219            True  mean absolute error        0.212500     0.333927
# 220            True  mean absolute error        0.452500     0.496345
# 221            True  mean absolute error        0.295000     0.416724
# 222            True  mean absolute error        0.295000     0.416724
# 223            True  mean absolute error        0.355000     0.000000
# 224            True                 None        0.000000     1.000000
#
#                        model
# 0                       None
# 1    DecisionTreeRegressor()
# 2    DecisionTreeRegressor()
# 3    DecisionTreeRegressor()
# 4    DecisionTreeRegressor()
# 5    DecisionTreeRegressor()
# 6    DecisionTreeRegressor()
# 7    DecisionTreeRegressor()
# 8    DecisionTreeRegressor()
# 9    DecisionTreeRegressor()
# 10   DecisionTreeRegressor()
# 11   DecisionTreeRegressor()
# 12   DecisionTreeRegressor()
# 13   DecisionTreeRegressor()
# 14   DecisionTreeRegressor()
# 15   DecisionTreeRegressor()
# 16                      None
# 17   DecisionTreeRegressor()
# 18   DecisionTreeRegressor()
# 19   DecisionTreeRegressor()
# 20   DecisionTreeRegressor()
# 21   DecisionTreeRegressor()
# 22   DecisionTreeRegressor()
# 23   DecisionTreeRegressor()
# 24   DecisionTreeRegressor()
# 25   DecisionTreeRegressor()
# 26   DecisionTreeRegressor()
# 27   DecisionTreeRegressor()
# 28   DecisionTreeRegressor()
# 29   DecisionTreeRegressor()
# 30   DecisionTreeRegressor()
# 31   DecisionTreeRegressor()
# 32                      None
# 33   DecisionTreeRegressor()
# 34   DecisionTreeRegressor()
# 35   DecisionTreeRegressor()
# 36   DecisionTreeRegressor()
# 37   DecisionTreeRegressor()
# 38   DecisionTreeRegressor()
# 39   DecisionTreeRegressor()
# 40   DecisionTreeRegressor()
# 41   DecisionTreeRegressor()
# 42   DecisionTreeRegressor()
# 43   DecisionTreeRegressor()
# 44   DecisionTreeRegressor()
# 45   DecisionTreeRegressor()
# 46   DecisionTreeRegressor()
# 47   DecisionTreeRegressor()
# 48                      None
# 49   DecisionTreeRegressor()
# 50   DecisionTreeRegressor()
# 51   DecisionTreeRegressor()
# 52   DecisionTreeRegressor()
# 53   DecisionTreeRegressor()
# 54   DecisionTreeRegressor()
# 55   DecisionTreeRegressor()
# 56   DecisionTreeRegressor()
# 57   DecisionTreeRegressor()
# 58   DecisionTreeRegressor()
# 59   DecisionTreeRegressor()
# 60   DecisionTreeRegressor()
# 61   DecisionTreeRegressor()
# 62   DecisionTreeRegressor()
# 63   DecisionTreeRegressor()
# 64                      None
# 65   DecisionTreeRegressor()
# 66   DecisionTreeRegressor()
# 67   DecisionTreeRegressor()
# 68   DecisionTreeRegressor()
# 69   DecisionTreeRegressor()
# 70   DecisionTreeRegressor()
# 71   DecisionTreeRegressor()
# 72   DecisionTreeRegressor()
# 73   DecisionTreeRegressor()
# 74   DecisionTreeRegressor()
# 75   DecisionTreeRegressor()
# 76   DecisionTreeRegressor()
# 77   DecisionTreeRegressor()
# 78   DecisionTreeRegressor()
# 79   DecisionTreeRegressor()
# 80                      None
# 81   DecisionTreeRegressor()
# 82   DecisionTreeRegressor()
# 83   DecisionTreeRegressor()
# 84   DecisionTreeRegressor()
# 85   DecisionTreeRegressor()
# 86   DecisionTreeRegressor()
# 87   DecisionTreeRegressor()
# 88   DecisionTreeRegressor()
# 89   DecisionTreeRegressor()
# 90   DecisionTreeRegressor()
# 91   DecisionTreeRegressor()
# 92   DecisionTreeRegressor()
# 93   DecisionTreeRegressor()
# 94   DecisionTreeRegressor()
# 95   DecisionTreeRegressor()
# 96                      None
# 97   DecisionTreeRegressor()
# 98   DecisionTreeRegressor()
# 99   DecisionTreeRegressor()
# 100  DecisionTreeRegressor()
# 101  DecisionTreeRegressor()
# 102  DecisionTreeRegressor()
# 103  DecisionTreeRegressor()
# 104  DecisionTreeRegressor()
# 105  DecisionTreeRegressor()
# 106  DecisionTreeRegressor()
# 107  DecisionTreeRegressor()
# 108  DecisionTreeRegressor()
# 109  DecisionTreeRegressor()
# 110  DecisionTreeRegressor()
# 111  DecisionTreeRegressor()
# 112                     None
# 113  DecisionTreeRegressor()
# 114  DecisionTreeRegressor()
# 115  DecisionTreeRegressor()
# 116  DecisionTreeRegressor()
# 117  DecisionTreeRegressor()
# 118  DecisionTreeRegressor()
# 119  DecisionTreeRegressor()
# 120  DecisionTreeRegressor()
# 121  DecisionTreeRegressor()
# 122  DecisionTreeRegressor()
# 123  DecisionTreeRegressor()
# 124  DecisionTreeRegressor()
# 125  DecisionTreeRegressor()
# 126  DecisionTreeRegressor()
# 127  DecisionTreeRegressor()
# 128                     None
# 129  DecisionTreeRegressor()
# 130  DecisionTreeRegressor()
# 131  DecisionTreeRegressor()
# 132  DecisionTreeRegressor()
# 133  DecisionTreeRegressor()
# 134  DecisionTreeRegressor()
# 135  DecisionTreeRegressor()
# 136  DecisionTreeRegressor()
# 137  DecisionTreeRegressor()
# 138  DecisionTreeRegressor()
# 139  DecisionTreeRegressor()
# 140  DecisionTreeRegressor()
# 141  DecisionTreeRegressor()
# 142  DecisionTreeRegressor()
# 143  DecisionTreeRegressor()
# 144                     None
# 145  DecisionTreeRegressor()
# 146  DecisionTreeRegressor()
# 147  DecisionTreeRegressor()
# 148  DecisionTreeRegressor()
# 149  DecisionTreeRegressor()
# 150  DecisionTreeRegressor()
# 151  DecisionTreeRegressor()
# 152  DecisionTreeRegressor()
# 153  DecisionTreeRegressor()
# 154  DecisionTreeRegressor()
# 155  DecisionTreeRegressor()
# 156  DecisionTreeRegressor()
# 157  DecisionTreeRegressor()
# 158  DecisionTreeRegressor()
# 159  DecisionTreeRegressor()
# 160                     None
# 161  DecisionTreeRegressor()
# 162  DecisionTreeRegressor()
# 163  DecisionTreeRegressor()
# 164  DecisionTreeRegressor()
# 165  DecisionTreeRegressor()
# 166  DecisionTreeRegressor()
# 167  DecisionTreeRegressor()
# 168  DecisionTreeRegressor()
# 169  DecisionTreeRegressor()
# 170  DecisionTreeRegressor()
# 171  DecisionTreeRegressor()
# 172  DecisionTreeRegressor()
# 173  DecisionTreeRegressor()
# 174  DecisionTreeRegressor()
# 175  DecisionTreeRegressor()
# 176                     None
# 177  DecisionTreeRegressor()
# 178  DecisionTreeRegressor()
# 179  DecisionTreeRegressor()
# 180  DecisionTreeRegressor()
# 181  DecisionTreeRegressor()
# 182  DecisionTreeRegressor()
# 183  DecisionTreeRegressor()
# 184  DecisionTreeRegressor()
# 185  DecisionTreeRegressor()
# 186  DecisionTreeRegressor()
# 187  DecisionTreeRegressor()
# 188  DecisionTreeRegressor()
# 189  DecisionTreeRegressor()
# 190  DecisionTreeRegressor()
# 191  DecisionTreeRegressor()
# 192                     None
# 193  DecisionTreeRegressor()
# 194  DecisionTreeRegressor()
# 195  DecisionTreeRegressor()
# 196  DecisionTreeRegressor()
# 197  DecisionTreeRegressor()
# 198  DecisionTreeRegressor()
# 199  DecisionTreeRegressor()
# 200  DecisionTreeRegressor()
# 201  DecisionTreeRegressor()
# 202  DecisionTreeRegressor()
# 203  DecisionTreeRegressor()
# 204  DecisionTreeRegressor()
# 205  DecisionTreeRegressor()
# 206  DecisionTreeRegressor()
# 207  DecisionTreeRegressor()
# 208                     None
# 209  DecisionTreeRegressor()
# 210  DecisionTreeRegressor()
# 211  DecisionTreeRegressor()
# 212  DecisionTreeRegressor()
# 213  DecisionTreeRegressor()
# 214  DecisionTreeRegressor()
# 215  DecisionTreeRegressor()
# 216  DecisionTreeRegressor()
# 217  DecisionTreeRegressor()
# 218  DecisionTreeRegressor()
# 219  DecisionTreeRegressor()
# 220  DecisionTreeRegressor()
# 221  DecisionTreeRegressor()
# 222  DecisionTreeRegressor()
# 223  DecisionTreeRegressor()
# 224                     None

# %% [markdown]
# Before we build a model for our data we will check for outliers by **Isolation Forest Technique**.

# %%
from sklearn.ensemble import IsolationForest

# %%
data2 = pd.read_csv('/content/Company_Data.csv')

# %%
data2=pd.get_dummies(data2)

# %%
#training the model
clf = IsolationForest(random_state=10, contamination=.015)
clf.fit(data2)
# Out:
# IsolationForest(contamination=0.015, random_state=10)

# %%
data2['anamoly'] = clf.predict(data2.iloc[:,0:15])

# %%
data2[data2['anamoly']==-1]
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 5    10.81        124     113           13         501     72   78         16
# 25   14.90        139      32            0         176     82   54         11
# 75    8.55         88     111           23         480     92   36         16
# 159   9.32        119      60            0         372     70   30         18
# 284   6.97        106      46           11         414     96   79         17
# 317   6.41        142      30            0         472    136   80         15
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 5                1               0                 0         1          0
# 25               0               1                 0         1          0
# 75               1               0                 0         1          0
# 159              1               0                 0         1          0
# 284              1               0                 0         1          0
# 317              0               1                 0         1          0
#
#      US_No  US_Yes  anamoly
# 5        0       1       -1
# 25       1       0       -1
# 75       0       1       -1
# 159      1       0       -1
# 284      1       0       -1
# 317      1       0       -1

# %% [markdown]
# These datapoints are **outliers** in our data.
#
# We can eliminate these points to improve our model. There are other methods of imputation as well, but here we will go with elimination.

# %%
df_final = df.drop([5,25,75,159,284,317])

# %%
df_final.shape
# Out:
# (394, 15)

# %% [markdown]
# 6 datapoints which were **outliers** were **dropped** from our data to **improve our model**.

# %% [markdown]
# **Model Building**

# %%
#divide data into dependent and independent variables
array = df_final.values
x = array[:,1:15]
y = array[:, 0]

# %%
#get train and test data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.1, random_state=0)

# %% [markdown]
# **Decision Tree for Regressor Model**

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(max_depth=4)
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
#fearture importance using Decision Tree
print(model.feature_importances_)
# Out:
# [0.0534372  0.02477461 0.03522582 0.0279263  0.26311226 0.08793021
#  0.         0.0303328  0.40158493 0.07567586 0.         0.
#  0.         0.        ]

# %%
df_final.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'Age', 'Education', 'ShelveLoc_Bad', 'ShelveLoc_Good',
#        'ShelveLoc_Medium', 'Urban_No', 'Urban_Yes', 'US_No', 'US_Yes'],
#       dtype='object')

# %% [markdown]
# Price, ShelveLoc_Good can be considered important features affecting our target variable - Sales.

# %%
#plot decision tree
tree.plot_tree(model)
# Out:
# [Text(0.5, 0.9, 'X[8] <= 0.5\nsquared_error = 7.814\nsamples = 354\nvalue = 7.326'),
#  Text(0.25, 0.7, 'X[4] <= 105.5\nsquared_error = 5.866\nsamples = 283\nvalue = 6.636'),
#  Text(0.125, 0.5, 'X[5] <= 54.5\nsquared_error = 5.504\nsamples = 91\nvalue = 8.049'),
#  Text(0.0625, 0.3, 'X[1] <= 57.5\nsquared_error = 3.973\nsamples = 34\nvalue = 9.556'),
#  Text(0.03125, 0.1, 'squared_error = 1.668\nsamples = 11\nvalue = 7.959'),
#  Text(0.09375, 0.1, 'squared_error = 3.273\nsamples = 23\nvalue = 10.32'),
#  Text(0.1875, 0.3, 'X[7] <= 0.5\nsquared_error = 4.254\nsamples = 57\nvalue = 7.15'),
#  Text(0.15625, 0.1, 'squared_error = 2.992\nsamples = 39\nvalue = 7.791'),
#  Text(0.21875, 0.1, 'squared_error = 4.169\nsamples = 18\nvalue = 5.761'),
#  Text(0.375, 0.5, 'X[9] <= 0.5\nsquared_error = 4.643\nsamples = 192\nvalue = 5.967'),
#  Text(0.3125, 0.3, 'X[3] <= 196.5\nsquared_error = 4.092\nsamples = 58\nvalue = 4.732'),
#  Text(0.28125, 0.1, 'squared_error = 3.664\nsamples = 24\nvalue = 3.789'),
#  Text(0.34375, 0.1, 'squared_error = 3.324\nsamples = 34\nvalue = 5.398'),
#  Text(0.4375, 0.3, 'X[0] <= 124.5\nsquared_error = 3.936\nsamples = 134\nvalue = 6.501'),
#  Text(0.40625, 0.1, 'squared_error = 2.977\nsamples = 46\nvalue = 5.483'),
#  Text(0.46875, 0.1, 'squared_error = 3.613\nsamples = 88\nvalue = 7.033'),
#  Text(0.75, 0.7, 'X[4] <= 109.5\nsquared_error = 6.112\nsamples = 71\nvalue = 10.077'),
#  Text(0.625, 0.5, 'X[5] <= 44.5\nsquared_error = 2.813\nsamples = 22\nvalue = 12.138'),
#  Text(0.5625, 0.3, 'X[3] <= 301.5\nsquared_error = 2.478\nsamples = 6\nvalue = 13.838'),
#  Text(0.53125, 0.1, 'squared_error = 0.167\nsamples = 3\nvalue = 12.527'),
#  Text(0.59375, 0.1, 'squared_error = 1.348\nsamples = 3\nvalue = 15.15'),
#  Text(0.6875, 0.3, 'X[0] <= 128.5\nsquared_error = 1.448\nsamples = 16\nvalue = 11.501'),
#  Text(0.65625, 0.1, 'squared_error = 1.204\nsamples = 13\nvalue = 11.189'),
#  Text(0.71875, 0.1, 'squared_error = 0.262\nsamples = 3\nvalue = 12.85'),
#  Text(0.875, 0.5, 'X[2] <= 13.5\nsquared_error = 4.829\nsamples = 49\nvalue = 9.152'),
#  Text(0.8125, 0.3, 'X[4] <= 142.5\nsquared_error = 3.878\nsamples = 42\nvalue = 8.704'),
#  Text(0.78125, 0.1, 'squared_error = 2.873\nsamples = 31\nvalue = 9.265'),
#  Text(0.84375, 0.1, 'squared_error = 3.32\nsamples = 11\nvalue = 7.122'),
#  Text(0.9375, 0.3, 'X[0] <= 122.5\nsquared_error = 2.114\nsamples = 7\nvalue = 11.839'),
#  Text(0.90625, 0.1, 'squared_error = 1.117\nsamples = 4\nvalue = 10.798'),
#  Text(0.96875, 0.1, 'squared_error = 0.071\nsamples = 3\nvalue = 13.227')]

# %%
#to get a better picture
fn=[ 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
       'Age', 'Education', 'ShelveLoc_Bad', 'ShelveLoc_Good',
       'ShelveLoc_Medium', 'Urban_No', 'Urban_Yes', 'US_No', 'US_Yes']
fig, axes=plt.subplots(nrows=1, ncols=1, figsize=(8,4), dpi=300)
tree.plot_tree(model, feature_names = fn, filled=True)
# Out:
# [Text(0.5, 0.9, 'ShelveLoc_Good <= 0.5\nsquared_error = 7.814\nsamples = 354\nvalue = 7.326'),
#  Text(0.25, 0.7, 'Price <= 105.5\nsquared_error = 5.866\nsamples = 283\nvalue = 6.636'),
#  Text(0.125, 0.5, 'Age <= 54.5\nsquared_error = 5.504\nsamples = 91\nvalue = 8.049'),
#  Text(0.0625, 0.3, 'Income <= 57.5\nsquared_error = 3.973\nsamples = 34\nvalue = 9.556'),
#  Text(0.03125, 0.1, 'squared_error = 1.668\nsamples = 11\nvalue = 7.959'),
#  Text(0.09375, 0.1, 'squared_error = 3.273\nsamples = 23\nvalue = 10.32'),
#  Text(0.1875, 0.3, 'ShelveLoc_Bad <= 0.5\nsquared_error = 4.254\nsamples = 57\nvalue = 7.15'),
#  Text(0.15625, 0.1, 'squared_error = 2.992\nsamples = 39\nvalue = 7.791'),
#  Text(0.21875, 0.1, 'squared_error = 4.169\nsamples = 18\nvalue = 5.761'),
#  Text(0.375, 0.5, 'ShelveLoc_Medium <= 0.5\nsquared_error = 4.643\nsamples = 192\nvalue = 5.967'),
#  Text(0.3125, 0.3, 'Population <= 196.5\nsquared_error = 4.092\nsamples = 58\nvalue = 4.732'),
#  Text(0.28125, 0.1, 'squared_error = 3.664\nsamples = 24\nvalue = 3.789'),
#  Text(0.34375, 0.1, 'squared_error = 3.324\nsamples = 34\nvalue = 5.398'),
#  Text(0.4375, 0.3, 'CompPrice <= 124.5\nsquared_error = 3.936\nsamples = 134\nvalue = 6.501'),
#  Text(0.40625, 0.1, 'squared_error = 2.977\nsamples = 46\nvalue = 5.483'),
#  Text(0.46875, 0.1, 'squared_error = 3.613\nsamples = 88\nvalue = 7.033'),
#  Text(0.75, 0.7, 'Price <= 109.5\nsquared_error = 6.112\nsamples = 71\nvalue = 10.077'),
#  Text(0.625, 0.5, 'Age <= 44.5\nsquared_error = 2.813\nsamples = 22\nvalue = 12.138'),
#  Text(0.5625, 0.3, 'Population <= 301.5\nsquared_error = 2.478\nsamples = 6\nvalue = 13.838'),
#  Text(0.53125, 0.1, 'squared_error = 0.167\nsamples = 3\nvalue = 12.527'),
#  Text(0.59375, 0.1, 'squared_error = 1.348\nsamples = 3\nvalue = 15.15'),
#  Text(0.6875, 0.3, 'CompPrice <= 128.5\nsquared_error = 1.448\nsamples = 16\nvalue = 11.501'),
#  Text(0.65625, 0.1, 'squared_error = 1.204\nsamples = 13\nvalue = 11.189'),
#  Text(0.71875, 0.1, 'squared_error = 0.262\nsamples = 3\nvalue = 12.85'),
#  Text(0.875, 0.5, 'Advertising <= 13.5\nsquared_error = 4.829\nsamples = 49\nvalue = 9.152'),
#  Text(0.8125, 0.3, 'Price <= 142.5\nsquared_error = 3.878\nsamples = 42\nvalue = 8.704'),
#  Text(0.78125, 0.1, 'squared_error = 2.873\nsamples = 31\nvalue = 9.265'),
#  Text(0.84375, 0.1, 'squared_error = 3.32\nsamples = 11\nvalue = 7.122'),
#  Text(0.9375, 0.3, 'CompPrice <= 122.5\nsquared_error = 2.114\nsamples = 7\nvalue = 11.839'),
#  Text(0.90625, 0.1, 'squared_error = 1.117\nsamples = 4\nvalue = 10.798'),
#  Text(0.96875, 0.1, 'squared_error = 0.071\nsamples = 3\nvalue = 13.227')]

# %%
pred = model.predict(x_test)

# %%
pred
# Out:
# array([ 7.03318182,  5.48304348, 11.18923077,  9.26548387,  5.48304348,
#        15.15      ,  5.48304348,  7.95909091,  7.95909091, 12.85      ,
#        10.31956522,  5.39794118, 12.85      ,  9.26548387,  9.26548387,
#         7.03318182,  7.79076923,  7.79076923,  7.03318182,  7.03318182,
#        10.31956522,  7.12181818,  5.48304348,  7.79076923,  7.79076923,
#         3.78916667, 11.18923077,  9.26548387,  5.48304348,  7.03318182,
#        10.31956522,  5.76055556,  5.39794118, 10.31956522,  5.76055556,
#        10.31956522,  7.03318182, 13.22666667,  5.48304348, 13.22666667])

# %%
y_test
# Out:
# array([ 5.08,  7.53,  9.46, 12.53,  6.18, 10.26,  8.65,  7.5 ,  8.79,
#        12.57, 11.91,  4.53, 12.66,  9.71,  8.77,  9.32, 11.48,  7.7 ,
#        10.27,  7.3 ,  7.63,  7.49,  7.32,  9.64,  9.33,  3.24, 14.37,
#         9.16,  6.44,  9.01,  6.64,  5.07,  5.83,  9.14, 11.18, 10.36,
#         4.9 , 12.57,  4.68, 11.85])

# %%
#find accuracy
model.score(x_test, y_test)
# Out:
# 0.3684585548241335

# %% [markdown]
# As the data we had was small so we selected the test data also a small quantity, to increase model accuracy.

# %% [markdown]
# **Random Forest Regressor**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score


seed = 7             #num of nodes(i) 
max_features = 4     #num of features to be selected in random forest(k)
k_fold = KFold(n_splits = 10, shuffle=True, random_state=seed)       #n_splits=k in KFold
model = RandomForestRegressor(n_estimators=1000, max_features=max_features, random_state=seed)  #n_estimators= num of trees
results = cross_val_score(model, x, y, cv=k_fold)
print(results.mean())
# Out:
# 0.6382020682664024

# %% [markdown]
# The best model we got by Random Forest was we selected 1000 decision trees and by selecting 4 features randomly.
#
# **Accuracy of the model we got is 63.8202.**

# %%
model.fit(x_train, y_train)
pred_rf = model.predict(x_test)

# %%
y_test
# Out:
# array([ 5.08,  7.53,  9.46, 12.53,  6.18, 10.26,  8.65,  7.5 ,  8.79,
#        12.57, 11.91,  4.53, 12.66,  9.71,  8.77,  9.32, 11.48,  7.7 ,
#        10.27,  7.3 ,  7.63,  7.49,  7.32,  9.64,  9.33,  3.24, 14.37,
#         9.16,  6.44,  9.01,  6.64,  5.07,  5.83,  9.14, 11.18, 10.36,
#         4.9 , 12.57,  4.68, 11.85])

# %%
pred_rf
# Out:
# array([ 5.97266,  6.99685, 10.11103, 10.11663,  7.3616 ,  9.41619,
#         8.91388,  6.82872,  8.83014, 11.94243,  9.0988 ,  5.89777,
#        11.30265, 10.24758, 10.35487,  7.70292,  9.29734,  8.1926 ,
#         8.75356,  7.29738,  7.74092,  8.23248,  6.13359,  8.00692,
#         8.2901 ,  5.02696, 10.87405,  9.86422,  7.98807,  8.2648 ,
#         6.71014,  5.48993,  5.48898,  7.08631,  7.36775,  9.13318,
#         6.35405, 10.93035,  5.41451, 10.45908])
